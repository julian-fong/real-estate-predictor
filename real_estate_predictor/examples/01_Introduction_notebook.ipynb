# %% [markdown]
# ### Welcome to the introductory notebook to the real estate predictor!
#
# If you haven't seen the steps on how to install the library, you can visit the main github page [here](https://github.com/julian-fong/real-estate-predictor)
#
# In this notebook, we'll explain the overview of the project and display some sample code.

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Quick prediction sample
#
# Note:
#
# For the below section - you'll need a [Repliers API KEY](https://repliers.com/) in order to properly generate a prediction using the sample models, as the `predict` function accepts an `mlsNumber` as a parameter

# %%
from real_estate_predictor.predict import predict_sale_listing

# %% [markdown]
# Lets take a sample listing in the GTA market. The listing "277 Calvert Rd" is a detached house in the GTA with 4 bedrooms and 5 bathrooms with 2 parking sports. It is currently listed for 2,180,000 dollars on the open market. Its corresponding mlsNumber is "N12174739".
#
# We can directly feed the mlsNumber into the predict method to have our machine learning model estimate its closing price

# %%
prediction = predict_sale_listing("N12174739")
prediction
# Out:
# {'mlsNumber': 'N12174739', 'prediction': 2352996.25}

# %% [markdown]
# ## Exploring some of the features in the project
#
# Below is a quick list of some of the things you can do with this library.
#
# - **Data Cleaning**: Handles missing values, removing bad/invalid values via pandas
#
# - **Feature Engineering**: Creates new features using existing predictors via pandas
#
# - **Data Preprocessing**: Scaling numerical predictors, encodes categorical variables, and splits the dataset into training, validation, and test sets via sklearn.
#
# We'll use some mock data in order to try some of the functions used in the library

# %% [markdown]
# ### Data Cleaning

# %%
from real_estate_predictor.tests.test_preprocessor import data
import pandas as pd

mock_data = pd.DataFrame(data)
mock_data.head()
# Out:
#                  class   type  listPrice                   listDate  \
# 0        CondoProperty  Lease     2200.0  2023-12-01 00:00:00+00:00
# 1        CondoProperty  Lease     2400.0  2023-12-02 00:00:00+00:00
# 2  ResidentialProperty   Sale   850000.0  2023-11-05 00:00:00+00:00
# 3        CondoProperty  Lease     2700.0  2023-10-15 00:00:00+00:00
# 4  ResidentialProperty   Sale        NaN  2023-10-20 00:00:00+00:00
#
#    soldPrice                   soldDate     city     area     district  \
# 0     2200.0  2023-12-31 00:00:00+00:00  Toronto  Toronto  Toronto C01
# 1     2400.0  2023-12-31 00:00:00+00:00  Toronto  Toronto  Toronto C02
# 2   820000.0  2023-12-31 00:00:00+00:00  Toronto  Toronto  Toronto C03
# 3     2600.0  2023-12-31 00:00:00+00:00  Toronto  Toronto  Toronto C04
# 4   570000.0  2023-12-31 00:00:00+00:00  Toronto  Toronto  Toronto C05
#
#      neighborhood  ... numBathrooms  numBedrooms      style  numKitchens  \
# 0  Neighborhood A  ...            1            1  Apartment            1
# 1  Neighborhood B  ...            2            2   2-Storey            1
# 2  Neighborhood C  ...            3            3   Bungalow            1
# 3  Neighborhood D  ...            1            1  Apartment            1
# 4  Neighborhood E  ...            2            2  Apartment            1
#
#    numRooms numParkingSpaces     sqft        propertyType  numGarageSpaces  \
# 0       5.0                0  500-599           Condo Apt                0
# 1       4.0                1  700-799            Detached                1
# 2       8.0                4  600-699  Comm Element Condo                1
# 3       4.0                2    0-499           Condo Apt                0
# 4       5.0                3      NaN            Detached                1
#
#   numDrivewaySpaces
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 23 columns]

# %%
from real_estate_predictor.processing.processor import DataCleaner

# %%
cleaner = DataCleaner(mock_data)
cleaner.handle_missing_values(strategy = "columns", columns = ["numDrivewaySpaces"])
# we can see that the missing values in the 'numDrivewaySpaces' column have been removed
cleaner.df.head()
# Out:
#                  class   type  listPrice                   listDate  \
# 0        CondoProperty  Lease     2200.0  2023-12-01 00:00:00+00:00
# 1        CondoProperty  Lease     2400.0  2023-12-02 00:00:00+00:00
# 2  ResidentialProperty   Sale   850000.0  2023-11-05 00:00:00+00:00
# 3        CondoProperty  Lease     2700.0  2023-10-15 00:00:00+00:00
# 4  ResidentialProperty   Sale        NaN  2023-10-20 00:00:00+00:00
#
#    soldPrice                   soldDate     city     area     district  \
# 0     2200.0  2023-12-31 00:00:00+00:00  Toronto  Toronto  Toronto C01
# 1     2400.0  2023-12-31 00:00:00+00:00  Toronto  Toronto  Toronto C02
# 2   820000.0  2023-12-31 00:00:00+00:00  Toronto  Toronto  Toronto C03
# 3     2600.0  2023-12-31 00:00:00+00:00  Toronto  Toronto  Toronto C04
# 4   570000.0  2023-12-31 00:00:00+00:00  Toronto  Toronto  Toronto C05
#
#      neighborhood  ... longitude  numBathrooms  numBedrooms      style  \
# 0  Neighborhood A  ...    -79.40             1            1  Apartment
# 1  Neighborhood B  ...    -79.41             2            2   2-Storey
# 2  Neighborhood C  ...    -79.42             3            3   Bungalow
# 3  Neighborhood D  ...    -79.43             1            1  Apartment
# 4  Neighborhood E  ...    -79.44             2            2  Apartment
#
#    numKitchens numRooms  numParkingSpaces     sqft        propertyType  \
# 0            1      5.0                 0  500-599           Condo Apt
# 1            1      4.0                 1  700-799            Detached
# 2            1      8.0                 4  600-699  Comm Element Condo
# 3            1      4.0                 2    0-499           Condo Apt
# 4            1      5.0                 3      NaN            Detached
#
#   numGarageSpaces
# 0               0
# 1               1
# 2               1
# 3               0
# 4               1
#
# [5 rows x 22 columns]

# %%
#this function will return the rows that are less than the threshold value
cleaner.filter_rows_by_threshold(columns = ["listPrice", "soldPrice"], threshold = 100000, strategy = "lt")
cleaner.df.head()
# Out:
#            class   type  listPrice                   listDate  soldPrice  \
# 0  CondoProperty  Lease     2200.0  2023-12-01 00:00:00+00:00     2200.0
# 1  CondoProperty  Lease     2400.0  2023-12-02 00:00:00+00:00     2400.0
# 3  CondoProperty  Lease     2700.0  2023-10-15 00:00:00+00:00     2600.0
# 7  CondoProperty  Lease     2900.0  2023-12-07 00:00:00+00:00     2800.0
# 9  CondoProperty  Lease     3100.0  2023-12-08 00:00:00+00:00     3000.0
#
#                     soldDate     city     area     district    neighborhood  \
# 0  2023-12-31 00:00:00+00:00  Toronto  Toronto  Toronto C01  Neighborhood A
# 1  2023-12-31 00:00:00+00:00  Toronto  Toronto  Toronto C02  Neighborhood B
# 3  2023-12-31 00:00:00+00:00  Toronto  Toronto  Toronto C04  Neighborhood D
# 7  2023-12-31 00:00:00+00:00  Toronto  Toronto  Toronto C08  Neighborhood H
# 9  2023-12-31 00:00:00+00:00  Toronto  Toronto  Toronto C10  Neighborhood J
#
#    ... longitude  numBathrooms  numBedrooms      style  numKitchens numRooms  \
# 0  ...    -79.40             1            1  Apartment            1      5.0
# 1  ...    -79.41             2            2   2-Storey            1      4.0
# 3  ...    -79.43             1            1  Apartment            1      4.0
# 7  ...    -79.47             2            2   Bungalow            1      NaN
# 9  ...    -79.49             2            3  Apartment            1      4.0
#
#    numParkingSpaces     sqft  propertyType numGarageSpaces
# 0                 0  500-599     Condo Apt               0
# 1                 1  700-799      Detached               1
# 3                 2    0-499     Condo Apt               0
# 7                 3  500-599     Condo Apt               1
# 9                 1  600-699     Condo Apt               0
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Feature Engineering
#
# The GTA datasets have base columns that can be used to define other columns that are derived from them. For example using the column name `sqft`, we can then feature engineer a common predictor that most agents/realtors use to gauge value called the price per square footage i.e `ppsqft`.

# %%
from real_estate_predictor.processing.processor import FeatureEngineering

# %%
feature = FeatureEngineering(cleaner.df)
feature.create_features_old(["sqft_avg", "ppsqft"])

# %%
feature.df.head()
# Out:
#            class   type  listPrice                   listDate  soldPrice  \
# 0  CondoProperty  Lease     2200.0  2023-12-01 00:00:00+00:00     2200.0
# 1  CondoProperty  Lease     2400.0  2023-12-02 00:00:00+00:00     2400.0
# 3  CondoProperty  Lease     2700.0  2023-10-15 00:00:00+00:00     2600.0
# 7  CondoProperty  Lease     2900.0  2023-12-07 00:00:00+00:00     2800.0
# 9  CondoProperty  Lease     3100.0  2023-12-08 00:00:00+00:00     3000.0
#
#                     soldDate     city     area     district    neighborhood  \
# 0  2023-12-31 00:00:00+00:00  Toronto  Toronto  Toronto C01  Neighborhood A
# 1  2023-12-31 00:00:00+00:00  Toronto  Toronto  Toronto C02  Neighborhood B
# 3  2023-12-31 00:00:00+00:00  Toronto  Toronto  Toronto C04  Neighborhood D
# 7  2023-12-31 00:00:00+00:00  Toronto  Toronto  Toronto C08  Neighborhood H
# 9  2023-12-31 00:00:00+00:00  Toronto  Toronto  Toronto C10  Neighborhood J
#
#    ... numBedrooms      style  numKitchens  numRooms  numParkingSpaces  \
# 0  ...           1  Apartment            1       5.0                 0
# 1  ...           2   2-Storey            1       4.0                 1
# 3  ...           1  Apartment            1       4.0                 2
# 7  ...           2   Bungalow            1       NaN                 3
# 9  ...           3  Apartment            1       4.0                 1
#
#       sqft  propertyType  numGarageSpaces  sqft_avg     ppsqft
# 0  500-599     Condo Apt                0     549.5   4.003640
# 1  700-799      Detached                1     749.5   3.202135
# 3    0-499     Condo Apt                0     249.5  10.821643
# 7  500-599     Condo Apt                1     549.5   5.277525
# 9  600-699     Condo Apt                0     649.5   4.772902
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Preprocessing
#
# Before we can train our model, we need to prepare our cleaned dataset into a format that is acceptable by the model.
#
# We can use the `Processor` module to help us.

# %%
from real_estate_predictor.tests.test_preprocessor import data as preprocessor_data

# %%
preprocessor_mock_data = pd.DataFrame(preprocessor_data)
preprocessor_mock_data.head()
# Out:
#                  class   type  listPrice                   listDate  \
# 0        CondoProperty  Lease     2200.0  2023-12-01 00:00:00+00:00
# 1        CondoProperty  Lease     2400.0  2023-12-02 00:00:00+00:00
# 2  ResidentialProperty   Sale   850000.0  2023-11-05 00:00:00+00:00
# 3        CondoProperty  Lease     2700.0  2023-10-15 00:00:00+00:00
# 4  ResidentialProperty   Sale        NaN  2023-10-20 00:00:00+00:00
#
#    soldPrice                   soldDate     city     area     district  \
# 0     2200.0  2023-12-31 00:00:00+00:00  Toronto  Toronto  Toronto C01
# 1     2400.0  2023-12-31 00:00:00+00:00  Toronto  Toronto  Toronto C02
# 2   820000.0  2023-12-31 00:00:00+00:00  Toronto  Toronto  Toronto C03
# 3     2600.0  2023-12-31 00:00:00+00:00  Toronto  Toronto  Toronto C04
# 4   570000.0  2023-12-31 00:00:00+00:00  Toronto  Toronto  Toronto C05
#
#      neighborhood  ... numBathrooms  numBedrooms      style  numKitchens  \
# 0  Neighborhood A  ...            1            1  Apartment            1
# 1  Neighborhood B  ...            2            2   2-Storey            1
# 2  Neighborhood C  ...            3            3   Bungalow            1
# 3  Neighborhood D  ...            1            1  Apartment            1
# 4  Neighborhood E  ...            2            2  Apartment            1
#
#    numRooms numParkingSpaces     sqft        propertyType  numGarageSpaces  \
# 0       5.0                0  500-599           Condo Apt                0
# 1       4.0                1  700-799            Detached                1
# 2       8.0                4  600-699  Comm Element Condo                1
# 3       4.0                2    0-499           Condo Apt                0
# 4       5.0                3      NaN            Detached                1
#
#   numDrivewaySpaces
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# First, lets setup our columns that we can to transform before feeding it into the model.

# %%
feature_transform_numerical1 = ["listPrice"]
feature_impute_encode_categorical1 = ["sqft"]

# %% [markdown]
# Now we can initialize our processor

# %%
from real_estate_predictor.processing.processor import Processor
processor = Processor(preprocessor_mock_data)

# %%
processor.transform_numerical(
    strategy="default", columns=feature_transform_numerical1
)
processor.encode_categorical(
    columns=feature_impute_encode_categorical1, strategy="onehot"
)

# %% [markdown]
# The code above only assigns the column to the particular strategy, but we haven't transformed anything yet. Once we use the `apply_transformer` function, the `processor` module will automatically create the necessary `sklearn` pipelines to transform the data

# %%
processor.apply_transformer()

# %%
processor.fit(preprocessor_mock_data)

# %% [markdown]
# We can see the newly processed data below

# %%
processed_data = processor.transform(preprocessor_mock_data)
processed_data.head()
# Out:
#    listPrice  sqft_0-499  sqft_500-599  sqft_600-699  sqft_700-799  \
# 0  -0.553172         0.0           1.0           0.0           0.0
# 1  -0.552940         0.0           0.0           0.0           1.0
# 2   0.429098         0.0           0.0           1.0           0.0
# 3  -0.552593         1.0           0.0           0.0           0.0
# 4        NaN         0.0           0.0           0.0           0.0
#
#    sqft_800-899  sqft_nan                class   type  \
# 0           0.0       0.0        CondoProperty  Lease
# 1           0.0       0.0        CondoProperty  Lease
# 2           0.0       0.0  ResidentialProperty   Sale
# 3           0.0       0.0        CondoProperty  Lease
# 4           0.0       1.0  ResidentialProperty   Sale
#
#                     listDate  ...  longitude numBathrooms numBedrooms  \
# 0  2023-12-01 00:00:00+00:00  ...     -79.40            1           1
# 1  2023-12-02 00:00:00+00:00  ...     -79.41            2           2
# 2  2023-11-05 00:00:00+00:00  ...     -79.42            3           3
# 3  2023-10-15 00:00:00+00:00  ...     -79.43            1           1
# 4  2023-10-20 00:00:00+00:00  ...     -79.44            2           2
#
#        style numKitchens numRooms numParkingSpaces        propertyType  \
# 0  Apartment           1      5.0                0           Condo Apt
# 1   2-Storey           1      4.0                1            Detached
# 2   Bungalow           1      8.0                4  Comm Element Condo
# 3  Apartment           1      4.0                2           Condo Apt
# 4  Apartment           1      5.0                3            Detached
#
#    numGarageSpaces  numDrivewaySpaces
# 0                0                NaN
# 1                1                NaN
# 2                1                NaN
# 3                0                NaN
# 4                1                NaN
#
# [5 rows x 28 columns]
