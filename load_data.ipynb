# %%
import pandas as pd
import numpy as np
import requests
import os
import datetime as dt

# %%
def get_dates(days):
    date_list = []
    today = dt.datetime.now()
    daysBehind = dt.timedelta(days = days)
    start_raw = today-daysBehind
    start_date = str(start_raw).split(" ")[0]

    current_date = start_raw
    date_list.append(start_date)
    while current_date <= (today- dt.timedelta(days = 14)):
        current_date = current_date + dt.timedelta(days = 7)
        date_list.append(str(current_date).split(" ")[0])

    return date_list

# %%
def get_data(type_, date_list, api_key):
    if type_.lower() == 'sale':
        lastStatus = ""
    else:
        lastStatus = "&lastStatus=Lsd"
    columns = ['rooms','occupancy', 'lot','timestamps','condominium','taxes', 'office', 'nearby', 'updatedOn', 'coopCompensation' ,'daysOnMarket','openHouse', 'permissions' ,'resource', 'images' ,'boardId' ,'agents']
    raw_df = pd.DataFrame()
    for i in range(len(date_list)):
        start_date = date_list[i]
        end_date = dt.datetime.strptime(start_date, '%Y-%m-%d') + dt.timedelta(days = 6)
        end_date = dt.datetime.strftime(end_date, '%Y-%m-%d')
        url = f'https://api.repliers.io/listings?resultsPerPage=10000&minSoldDate={start_date}&maxSoldDate={end_date}&status=U'+lastStatus+f"&type={type_}"

        payload = {}
        headers = {'repliers-api-key': api_key}
        r = requests.request("GET",url, params=payload, headers=headers)
        data = r.json()
        df = pd.DataFrame(data['listings'])
        df = df.drop(columns, axis = 1)
        #Raw Dataset
        
        raw_df = pd.concat([raw_df, df],axis = 0, ignore_index= True)
        print(len(raw_df))

    return raw_df

# %%
def import_data(days_amount, type_, api_key, save = False):
    dates = get_dates(days_amount)
    if not type_:
        raw_lease_data = get_data('lease', dates, api_key)
        raw_sale_data = get_data('sale', dates, api_key)
        if save:
            raw_lease_data.to_csv(os.getcwd()+"\\data\\raw_lease_data.csv", index = False)
            raw_sale_data.to_csv(os.getcwd()+"\\data\\raw_sale_data.csv", index = False)
        else:
            return raw_lease_data, raw_sale_data
    else:
        raw_data = get_data(type_, dates, api_key)
        if save:
            raw_data.to_csv(os.getcwd()+f"\\data\\raw_{type_}_data.csv", index = False)
        else:
            return raw_data

# %%
import_data(10, 'sale', os.environ['REPLIERS_KEY'], False)
# Out:
# 2604
#                       listDate originalPrice                  soldDate  type  \
# 0     2023-04-22T00:00:00.000Z    1499900.00  2023-05-04T00:00:00.000Z  Sale
# 1     2023-05-01T00:00:00.000Z    1499900.00  2023-05-04T00:00:00.000Z  Sale
# 2     2023-04-27T00:00:00.000Z     724900.00  2023-05-04T00:00:00.000Z  Sale
# 3     2023-01-12T00:00:00.000Z     849900.00  2023-05-04T00:00:00.000Z  Sale
# 4     2023-03-23T00:00:00.000Z    1249900.00  2023-05-04T00:00:00.000Z  Sale
# ...                        ...           ...                       ...   ...
# 2599  2023-04-24T00:00:00.000Z    1648000.00  2023-04-28T00:00:00.000Z  Sale
# 2600  2023-04-20T00:00:00.000Z    1299000.00  2023-04-28T00:00:00.000Z  Sale
# 2601  2023-04-20T00:00:00.000Z    1028000.00  2023-04-28T00:00:00.000Z  Sale
# 2602  2023-04-13T00:00:00.000Z     489000.00  2023-04-28T00:00:00.000Z  Sale
# 2603  2023-04-12T00:00:00.000Z     599900.00  2023-04-28T00:00:00.000Z  Sale
#
#      mlsNumber   soldPrice                                            details  \
# 0     W6043173  1513000.00  {'numKitchens': '1', 'numParkingSpaces': '6.0'...
# 1     E5922888  1490000.00  {'numKitchens': '2', 'numParkingSpaces': '8.0'...
# 2     N6050621   717500.00  {'numKitchens': '1', 'numParkingSpaces': '4.0'...
# 3     X5868052   794000.00  {'numKitchens': '1', 'numParkingSpaces': '4.0'...
# 4     S5904000  1190000.00  {'numKitchens': '1', 'numParkingSpaces': '12.0...
# ...        ...         ...                                                ...
# 2599  C6044393  1590000.00  {'numKitchens': '1', 'numParkingSpaces': '1.0'...
# 2600  C6038891  1170000.00  {'numKitchens': '1', 'numParkingSpaces': '3.0'...
# 2601  W6039767  1038000.00  {'numKitchens': '1', 'numParkingSpaces': '6.0'...
# 2602  C6023797   489000.00  {'numKitchens': '1', 'numParkingSpaces': '0.0'...
# 2603  W6025591   595000.00  {'numKitchens': '1', 'numParkingSpaces': '1.0'...
#
#                     class                                                map  \
# 0     ResidentialProperty  {'latitude': '43.4727843', 'point': 'POINT (-7...
# 1     ResidentialProperty  {'latitude': '43.7807432', 'point': 'POINT (-7...
# 2     ResidentialProperty  {'latitude': '44.3254076', 'point': 'POINT (-7...
# 3     ResidentialProperty  {'latitude': '43.30822630000001', 'point': 'PO...
# 4     ResidentialProperty  {'latitude': '44.4856294', 'point': 'POINT (-8...
# ...                   ...                                                ...
# 2599        CondoProperty  {'latitude': '43.6472244', 'point': 'POINT (-7...
# 2600  ResidentialProperty  {'latitude': '43.7587892', 'point': 'POINT (-7...
# 2601  ResidentialProperty  {'latitude': '43.9210831', 'point': 'POINT (-8...
# 2602        CondoProperty  {'latitude': '43.70432539999999', 'point': 'PO...
# 2603        CondoProperty  {'latitude': '43.6097383', 'point': 'POINT (-7...
#
#                                                 address   raw   listPrice  \
# 0     {'area': 'Halton', 'zip': 'L9E 1X3', 'country'...  None  1499900.00
# 1     {'area': 'Toronto', 'zip': 'M1C 1S1', 'country...  None  1499900.00
# 2     {'area': 'Simcoe', 'zip': 'L0M 1B3', 'country'...  None   724900.00
# 3     {'area': 'Oxford', 'zip': 'N0J 1S0', 'country'...  None   819999.00
# 4     {'area': 'Simcoe', 'zip': 'L9Z 2V6', 'country'...  None  1249900.00
# ...                                                 ...   ...         ...
# 2599  {'area': 'Toronto', 'zip': 'M5V 1V1', 'country...  None  1648000.00
# 2600  {'area': 'Toronto', 'zip': 'M3H 3Y4', 'country...  None  1299000.00
# 2601  {'area': 'Dufferin', 'zip': 'L9W 4Y3', 'countr...  None  1028000.00
# 2602  {'area': 'Toronto', 'zip': 'M4S 1V5', 'country...  None   489000.00
# 2603  {'area': 'Toronto', 'zip': 'M9C0A5', 'country'...  None   599900.00
#
#      lastStatus status
# 0           Sld      U
# 1           Sld      U
# 2           Sld      U
# 3           Sld      U
# 4           Sld      U
# ...         ...    ...
# 2599        Sld      U
# 2600        Sld      U
# 2601        Sld      U
# 2602        Sld      U
# 2603        Sld      U
#
# [2604 rows x 14 columns]
