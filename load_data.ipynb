# %%
import pandas as pd
import numpy as np
import requests
import os
import datetime as dt

# %%
def get_dates(days):
    date_list = []
    today = dt.datetime.now()
    daysBehind = dt.timedelta(days = days)
    start_raw = today-daysBehind
    start_date = str(start_raw).split(" ")[0]

    current_date = start_raw
    date_list.append(start_date)
    while current_date <= (today- dt.timedelta(days = 14)):
        current_date = current_date + dt.timedelta(days = 7)
        date_list.append(str(current_date).split(" ")[0])

    return date_list

# %%
def get_data(type_, date_list, api_key):
    if type_.lower() == 'sale':
        lastStatus = ""
    else:
        lastStatus = "&lastStatus=Lsd"
    columns = ['rooms','occupancy', 'lot','timestamps','condominium','taxes', 'office', 'nearby', 'updatedOn', 'coopCompensation' ,'daysOnMarket','openHouse', 'permissions' ,'resource', 'images' ,'boardId' ,'agents']
    raw_df = pd.DataFrame()
    for i in range(len(date_list)):
        start_date = date_list[i]
        end_date = dt.datetime.strptime(start_date, '%Y-%m-%d') + dt.timedelta(days = 6)
        end_date = dt.datetime.strftime(end_date, '%Y-%m-%d')
        url = f'https://api.repliers.io/listings?resultsPerPage=10000&minSoldDate={start_date}&maxSoldDate={end_date}&status=U'+lastStatus+f"&type={type_}"

        payload = {}
        headers = {'repliers-api-key': api_key}
        r = requests.request("GET",url, params=payload, headers=headers)
        data = r.json()
        df = pd.DataFrame(data['listings'])
        df = df.drop(columns, axis = 1)
        #Raw Dataset
        
        raw_df = pd.concat([raw_df, df],axis = 0, ignore_index= True)
        print(len(raw_df))

    return raw_df

# %%
def import_data(days_amount, type_, api_key, save = False):
    dates = get_dates(days_amount)
    if not type_:

        raw_lease_data = get_data('lease', dates, api_key)
        if save:
            raw_lease_data.to_csv(os.getcwd()+"\\data\\raw_lease_data.csv", index = False)

        raw_sale_data = get_data('sale', dates, api_key)
        if save:
            raw_sale_data.to_csv(os.getcwd()+"\\data\\raw_sale_data.csv", index = False)
            
        return raw_sale_data
    else:
        raw_data = get_data(type_, dates, api_key)
        if save:
            raw_data.to_csv(os.getcwd()+f"\\data\\raw_{type_}_data.csv", index = False)
        else:
            return raw_data

# %%
import_data(1460, None, os.environ['REPLIERS_KEY'], True)
# Out:
# 1399
# 2676
# 4098
# 5532
# 7069
# 8602
# 10187
# 11518
# 13163
# 14837
# 16600
# 18270
# 19634
# 21289
# 22954
# 24531
# 25757
# 27006
# 28313
# 29573
# 30789
# 31986
# 32956
# 34137
# 35278
# 36353
# 37430
# 38501
# 39578
# 40644
# 41594
# 42572
# 43314
# 43879
# 44718
# 45790
# 46802
# 47922
# 49028
# 50187
# 51203
# 52502
# 53770
# 55127
# 56435
# 57352
# 57982
# 58536
# 59099
# 59771
# 60590
# 61491
# 62589
# 63680
# 64846
# 66196
# 67659
# 69136
# 70682
# 72181
# 73798
# 75714
# 77557
# 79451
# 81202
# 83153
# 85064
# 86860
# 88539
# 90009
# 91681
# 93402
# 95020
# 96591
# 98052
# 99680
# 101337
# 102876
# 104407
# 106051
# 107586
# 109134
# 110610
# 112030
# 113419
# 114325
# 115406
# 117036
# 118651
# 120076
# 121581
# 123164
# 124665
# 126312
# 127937
# 129798
# 131684
# 133419
# 135198
# 136736
# 138629
# 140490
# 142229
# 143891
# 145685
# 147401
# 149044
# 150808
# 152712
# 154556
# 156463
# 158511
# 160376
# 162827
# 165310
# 167522
# 169501
# 171744
# 173869
# 175845
# 177762
# 179214
# 181017
# 182729
# 184439
# 186013
# 187436
# 189084
# 190802
# 192395
# 194052
# 195681
# 197404
# 198986
# 200373
# 201796
# 203162
# 203990
# 204927
# 516976  2023-04-23T00:00:00.000Z     899900.00  2023-04-27T00:00:00.000Z
# 516977  2023-04-12T00:00:00.000Z    1039900.00  2023-04-27T00:00:00.000Z
#
#         type mlsNumber   soldPrice  \
# 0       Sale  N4400080  1480000.00
# 1       Sale  N4409516   615000.00
# 2       Sale  W4434683   885000.00
# 3       Sale  W4442890   841000.00
# 4       Sale  N4426576   663000.00
# ...      ...       ...         ...
# 516973  Sale  E6039847   750000.00
# 516974  Sale  E5990057   673000.00
# 516975  Sale  C6035753   830000.00
# 516976  Sale  C6044325   890000.00
# 516977  Sale  C5907648  1039900.00
#
#                                                   details  \
# 0       {'numKitchens': None, 'numParkingSpaces': '5.0...
# 1       {'numKitchens': None, 'numParkingSpaces': '4.0...
# 2       {'numKitchens': None, 'numParkingSpaces': '6.0...
# 3       {'numKitchens': None, 'numParkingSpaces': '6.0...
# 4       {'numKitchens': None, 'numParkingSpaces': '4.0...
# ...                                                   ...
# 516973  {'numKitchens': '1', 'numParkingSpaces': '5.0'...
# 516974  {'numKitchens': '1', 'numParkingSpaces': '1.0'...
# 516975  {'numKitchens': '1', 'numParkingSpaces': '0.0'...
# 516976  {'numKitchens': '1', 'numParkingSpaces': '1.0'...
# 516977  {'numKitchens': '1', 'numParkingSpaces': '0.0'...
#
#                       class  \
# 0       ResidentialProperty
# 1       ResidentialProperty
# 2       ResidentialProperty
# 3       ResidentialProperty
# 4       ResidentialProperty
# ...                     ...
# 516973  ResidentialProperty
# 516974        CondoProperty
# 516975        CondoProperty
# 516976        CondoProperty
# 516977        CondoProperty
#
#                                                       map  \
# 0       {'latitude': '43.8797315', 'point': 'POINT (-7...
# 1       {'latitude': '44.31391250000001', 'point': 'PO...
# 2       {'latitude': '43.734903', 'point': 'POINT (-79...
# 3       {'latitude': '43.6223313', 'point': 'POINT (-7...
# 4       {'latitude': '43.8893334', 'point': 'POINT (-7...
# ...                                                   ...
# 516973  {'latitude': '43.8620964', 'point': 'POINT (-7...
# 516974  {'latitude': '43.8275826', 'point': 'POINT (-7...
# 516975  {'latitude': '43.67015869999999', 'point': 'PO...
# 516976  {'latitude': '43.6388301', 'point': 'POINT (-7...
# 516977  {'latitude': '43.6545291', 'point': 'POINT (-7...
#
#                                                   address   listPrice  \
# 0       {'area': 'York', 'zip': 'L6A0L4', 'country': N...  1499000.00
# 1       {'area': 'Simcoe', 'zip': 'L0M1B6', 'country':...   634900.00
# 2       {'area': 'Peel', 'zip': 'L6R2H6', 'country': N...   899000.00
# 3       {'area': 'Peel', 'zip': 'L4Z3T8', 'country': N...   848800.00
# 4       {'area': 'York', 'zip': 'L4C2X7', 'country': N...   692000.00
# ...                                                   ...         ...
# 516973  {'area': 'Durham', 'zip': 'L1J 7Z5', 'country'...   700000.00
# 516974  {'area': 'Durham', 'zip': 'L1W 1L7', 'country'...   684900.00
# 516975  {'area': 'Toronto', 'zip': 'M4W 0A8', 'country...   849000.00
# 516976  {'area': 'Toronto', 'zip': 'M6K 0B2', 'country...   899900.00
# 516977  {'area': 'Toronto', 'zip': 'M5A 3A6', 'country...  1039900.00
#
#        lastStatus status   raw bathrooms
# 0             Sld      U   NaN       NaN
# 1             Sld      U   NaN       NaN
# 2             Sld      U   NaN       NaN
# 3             Sld      U   NaN       NaN
# 4             Sld      U   NaN       NaN
# ...           ...    ...   ...       ...
# 516973        Sld      U  None       NaN
# 516974        Sld      U  None       NaN
# 516975        Sld      U  None       NaN
# 516976        Sld      U  None       NaN
# 516977        Sld      U  None       NaN
#
# [516978 rows x 15 columns]
